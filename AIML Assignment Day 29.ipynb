# %%
import numpy as np

# Considering sample data as follows
# X = (hours studying, hours sleeping), y = score on test
xAll = np.array(([2, 9], [1, 5], [3, 6], [5, 10]), dtype=float)  # input data
y = np.array(([92], [86], [89]), dtype=float)  # output

# scale units
xAll = xAll / np.amax(xAll, axis=0)  # scaling input data
y = y / 100  # scaling output data (max test score is 100)

# split data
X = np.split(xAll, [3])[0]  # training data
xPredicted = np.split(xAll, [3])[1]  # testing data

y = np.array(([92], [86], [89]), dtype=float)
y = y / 100  # max test score is 100


class Neural_Network(object):
    def __init__(self):
        #parameters
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3

        #weights
        self.W1 = np.random.randn(
            self.inputSize,
            self.hiddenSize)  # (3x2) weight matrix from input to hidden layer
        self.W2 = np.random.randn(
            self.hiddenSize,
            self.outputSize)  # (3x1) weight matrix from hidden to output layer

    def forward(self, X):
        #forward propagation through our network
        self.z = np.dot(
            X,
            self.W1)  # dot product of X (input) and first set of 3x2 weights
        self.z2 = self.sigmoid(self.z)  # activation function
        self.z3 = np.dot(
            self.z2, self.W2
        )  # dot product of hidden layer (z2) and second set of 3x1 weights
        o = self.sigmoid(self.z3)  # final activation function
        return o

    def sigmoid(self, s):
        # activation function
        return 1 / (1 + np.exp(-s))

    def sigmoidPrime(self, s):
        #derivative of sigmoid
        return s * (1 - s)

    def backward(self, X, y, o):
        # backward propagate through the network
        self.o_error = y - o  # error in output
        self.o_delta = self.o_error * self.sigmoidPrime(
            o)  # applying derivative of sigmoid to error

        self.z2_error = self.o_delta.dot(
            self.W2.T
        )  # z2 error: how much our hidden layer weights contributed to output error
        self.z2_delta = self.z2_error * self.sigmoidPrime(
            self.z2)  # applying derivative of sigmoid to z2 error

        self.W1 += X.T.dot(
            self.z2_delta)  # adjusting first set (input --> hidden) weights
        self.W2 += self.z2.T.dot(
            self.o_delta)  # adjusting second set (hidden --> output) weights

    def train(self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)

    def saveWeights(self):
        np.savetxt("w1.txt", self.W1, fmt="%s")
        np.savetxt("w2.txt", self.W2, fmt="%s")

    def predict(self):
        print("Predicted data based on trained weights: ")
        print("Input (scaled): \n" + str(xPredicted))
        print("Output: \n" + str(self.forward(xPredicted)))


NN = Neural_Network()
for i in range(1000):  # trains the NN 1,000 times
    print("--> " + str(i) + "\n")
    print("Input (scaled): \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" +
          str(np.mean(np.square(y - NN.forward(X)))))  # mean sum squared loss
    print("\n")
    NN.train(X, y)

NN.saveWeights()
NN.predict()
# Out:
# --> 0
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.48904539]
#  [0.4479882 ]
#  [0.45289754]]
# Loss:
# 0.18217805626708874
#
#
# --> 1
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.58116746]
#  [0.53158542]
#  [0.54042112]]
# Loss:
# 0.114956338722222
#
#
# --> 2
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.65019361]
#  [0.59640599]
#  [0.60788073]]
# Loss:
# 0.07395619121407476
#
#
# --> 3
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.69934166]
#  [0.64403648]
#  [0.65715162]]
# Loss:
# 0.04984957199976809
#
#
# --> 4
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.73465774]
#  [0.67918147]
#  [0.69330831]]
# Loss:
# 0.03524490474910525
#
#
# --> 5
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.76079471]
#  [0.70576576]
#  [0.72052626]]
# Loss:
# 0.025951957283302532
#
#
# --> 6
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.78076425]
#  [0.72644701]
#  [0.74161114]]
# Loss:
# 0.01974741618398528
#
#
# --> 7
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.79646473]
#  [0.74295466]
#  [0.75837846]]
# Loss:
# 0.015428267711256443
#
#
# --> 8
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.80911358]
#  [0.75642549]
#  [0.77201614]]
# Loss:
# 0.01231455612096763
#
#
# --> 9
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81951485]
#  [0.7676255 ]
#  [0.78332159]]
# Loss:
# 0.01000353202865087
#
#
# --> 10
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82821638]
#  [0.77708551]
#  [0.7928455 ]]
# Loss:
# 0.008246014293836477
#
#
# --> 11
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83560254]
#  [0.78518338]
#  [0.80097868]]
# Loss:
# 0.006881750997161911
#
#
# --> 12
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84195026]
#  [0.79219481]
#  [0.8080055 ]]
# Loss:
# 0.005804134289192675
#
#
# --> 13
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84746381]
#  [0.79832547]
#  [0.81413754]]
# Loss:
# 0.004940119961638838
#
#
# --> 14
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85229701]
#  [0.80373183]
#  [0.81953539]]
# Loss:
# 0.004238354567069755
#
#
# --> 15
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85656791]
#  [0.80853501]
#  [0.82432312]]
# Loss:
# 0.0036619094229592866
#
#
# --> 16
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86036857]
#  [0.8128303 ]
#  [0.82859808]]
# Loss:
# 0.0031836947875789195
#
#
# --> 17
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86377184]
#  [0.81669366]
#  [0.83243778]]
# Loss:
# 0.0027834847562619833
#
#
# --> 18
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86683616]
#  [0.82018644]
#  [0.83590468]]
# Loss:
# 0.002445938942816209
#
#
# --> 19
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86960893]
#  [0.82335876]
#  [0.83904971]]
# Loss:
# 0.00215925753159896
#
#
# --> 20
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87212904]
#  [0.82625194]
#  [0.84191481]]
# Loss:
# 0.0019142485016449158
#
#
# --> 21
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87442869]
#  [0.82890042]
#  [0.84453487]]
# Loss:
# 0.0017036689346724275
#
#
# --> 22
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87653477]
#  [0.8313331 ]
#  [0.84693912]]
# Loss:
# 0.0015217521937506513
#
#
# --> 23
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87846993]
#  [0.83357446]
#  [0.8491523 ]]
# Loss:
# 0.001363863424316569
#
#
# --> 24
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8802534 ]
#  [0.83564534]
#  [0.85119544]]
# Loss:
# 0.0012262451064246364
#
#
# --> 25
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88190159]
#  [0.83756365]
#  [0.85308657]]
# Loss:
# 0.0011058267549158092
#
#
# --> 26
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88342861]
#  [0.83934482]
#  [0.85484123]]
# Loss:
# 0.0010000809491175248
#
#
# --> 27
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88484665]
#  [0.84100226]
#  [0.85647288]]
# Loss:
# 0.0009069132509041455
#
#
# --> 28
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88616633]
#  [0.84254766]
#  [0.85799328]]
# Loss:
# 0.0008245772038037302
#
#
# --> 29
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8873969 ]
#  [0.84399128]
#  [0.8594127 ]]
# Loss:
# 0.0007516080981110242
#
#
# --> 30
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88854649]
#  [0.84534215]
#  [0.86074018]]
# Loss:
# 0.0006867709199027905
#
#
# --> 31
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88962227]
#  [0.84660825]
#  [0.86198373]]
# Loss:
# 0.0006290191222868047
#
#
# --> 32
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89063057]
#  [0.84779666]
#  [0.86315041]]
# Loss:
# 0.0005774617270142664
#
#
# --> 33
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89157705]
#  [0.84891372]
#  [0.86424654]]
# Loss:
# 0.0005313368914250614
#
#
# --> 34
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8924667 ]
#  [0.84996505]
#  [0.86527776]]
# Loss:
# 0.0004899905321739872
#
#
# --> 35
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89330405]
#  [0.85095574]
#  [0.86624912]]
# Loss:
# 0.00045285893287117294
#
#
# --> 36
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8940931 ]
#  [0.85189035]
#  [0.86716516]]
# Loss:
# 0.0004194545119056672
#
#
# --> 37
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89483751]
#  [0.85277298]
#  [0.86802998]]
# Loss:
# 0.00038935411322933955
#
#
# --> 38
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89554055]
#  [0.85360738]
#  [0.86884728]]
# Loss:
# 0.00036218932364714853
#
#
# --> 39
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89620518]
#  [0.8543969 ]
#  [0.86962042]]
# Loss:
# 0.0003376384272287135
#
#
# --> 40
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89683411]
#  [0.85514464]
#  [0.87035246]]
# Loss:
# 0.0003154196894887941
#
#
# --> 41
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89742977]
#  [0.8558534 ]
#  [0.87104617]]
# Loss:
# 0.0002952857272712532
#
#
# --> 42
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89799442]
#  [0.85652574]
#  [0.87170409]]
# Loss:
# 0.00027701876941692614
#
#
# --> 43
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89853009]
#  [0.857164  ]
#  [0.87232855]]
# Loss:
# 0.0002604266516985447
#
#
# --> 44
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89903865]
#  [0.85777034]
#  [0.87292169]]
# Loss:
# 0.000245339419692384
#
#
# --> 45
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89952182]
#  [0.85834674]
#  [0.87348545]]
# Loss:
# 0.00023160643711836134
#
#
# --> 46
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89998118]
#  [0.85889502]
#  [0.87402165]]
# Loss:
# 0.0002190939161448832
#
#
# --> 47
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90041818]
#  [0.85941687]
#  [0.87453194]]
# Loss:
# 0.00020768280130391704
#
#
# --> 48
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90083417]
#  [0.85991385]
#  [0.87501787]]
# Loss:
# 0.00019726695082350357
#
#
# --> 49
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90123038]
#  [0.86038738]
#  [0.87548084]]
# Loss:
# 0.00018775156899297825
#
#
# --> 50
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90160796]
#  [0.86083881]
#  [0.87592218]]
# Loss:
# 0.00017905185112283164
#
#
# --> 51
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90196798]
#  [0.86126937]
#  [0.87634311]]
# Loss:
# 0.00017109180912623537
#
#
# --> 52
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90231143]
#  [0.86168023]
#  [0.87674477]]
# Loss:
# 0.0001638032510315521
#
#
# --> 53
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90263922]
#  [0.86207245]
#  [0.87712821]]
# Loss:
# 0.0001571248920676327
#
#
# --> 54
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90295221]
#  [0.86244703]
#  [0.87749442]]
# Loss:
# 0.00015100157853076488
#
#
# --> 55
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90325119]
#  [0.86280491]
#  [0.87784431]]
# Loss:
# 0.0001453836085898855
#
#
# --> 56
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90353692]
#  [0.86314697]
#  [0.87817875]]
# Loss:
# 0.00014022613663092505
#
#
# --> 57
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90381008]
#  [0.86347401]
#  [0.87849854]]
# Loss:
# 0.0001354886497749291
#
#
# --> 58
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90407133]
#  [0.8637868 ]
#  [0.87880442]]
# Loss:
# 0.00013113450690235864
#
#
# --> 59
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90432127]
#  [0.86408607]
#  [0.87909711]]
# Loss:
# 0.0001271305319374873
#
#
# --> 60
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90456048]
#  [0.86437249]
#  [0.87937726]]
# Loss:
# 0.0001234466543408374
#
#
# --> 61
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9047895 ]
#  [0.86464668]
#  [0.87964549]]
# Loss:
# 0.0001200555907633916
#
#
# --> 62
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90500882]
#  [0.86490924]
#  [0.8799024 ]]
# Loss:
# 0.000116932562665748
#
#
# --> 63
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90521892]
#  [0.86516074]
#  [0.88014852]]
# Loss:
# 0.00011405504542520202
#
#
# --> 64
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90542025]
#  [0.8654017 ]
#  [0.88038437]]
# Loss:
# 0.00011140254506460112
#
#
# --> 65
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561323]
#  [0.86563263]
#  [0.88061045]]
# Loss:
# 0.00010895639925733666
#
#
# --> 66
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90579825]
#  [0.86585398]
#  [0.88082721]]
# Loss:
# 0.00010669959970675947
#
#
# --> 67
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90597568]
#  [0.8660662 ]
#  [0.88103509]]
# Loss:
# 0.00010461663337826326
#
#
# --> 68
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90614589]
#  [0.86626972]
#  [0.88123449]]
# Loss:
# 0.00010269334038806199
#
#
# --> 69
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90630919]
#  [0.86646492]
#  [0.8814258 ]]
# Loss:
# 0.00010091678663263142
#
#
# --> 70
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90646591]
#  [0.86665219]
#  [0.8816094 ]]
# Loss:
# 9.927514948389724e-05
#
#
# --> 71
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90661635]
#  [0.86683188]
#  [0.88178562]]
# Loss:
# 9.775761508342898e-05
#
#
# --> 72
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90676078]
#  [0.86700433]
#  [0.8819548 ]]
# Loss:
# 9.63542859487553e-05
#
#
# --> 73
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90689948]
#  [0.86716985]
#  [0.88211724]]
# Loss:
# 9.50560977610218e-05
#
#
# --> 74
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90703269]
#  [0.86732875]
#  [0.88227326]]
# Loss:
# 9.385474433848305e-05
#
#
# --> 75
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90716067]
#  [0.86748132]
#  [0.88242311]]
# Loss:
# 9.274260991818083e-05
#
#
# --> 76
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90728363]
#  [0.86762783]
#  [0.88256708]]
# Loss:
# 9.171270797074853e-05
#
#
# --> 77
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9074018 ]
#  [0.86776854]
#  [0.88270542]]
# Loss:
# 9.075862586289946e-05
#
#
# --> 78
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90751537]
#  [0.8679037 ]
#  [0.88283836]]
# Loss:
# 8.987447476044363e-05
#
#
# --> 79
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90762456]
#  [0.86803354]
#  [0.88296613]]
# Loss:
# 8.905484423334165e-05
#
#
# --> 80
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90772954]
#  [0.86815828]
#  [0.88308896]]
# Loss:
# 8.829476108447735e-05
#
#
# --> 81
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90783048]
#  [0.86827815]
#  [0.88320705]]
# Loss:
# 8.758965197670276e-05
#
#
# --> 82
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90792757]
#  [0.86839333]
#  [0.8833206 ]]
# Loss:
# 8.693530947927179e-05
#
#
# --> 83
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90802096]
#  [0.86850404]
#  [0.8834298 ]]
# Loss:
# 8.632786119582189e-05
#
#
# --> 84
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9081108 ]
#  [0.86861044]
#  [0.88353483]]
# Loss:
# 8.576374167218412e-05
#
#
# --> 85
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90819725]
#  [0.86871273]
#  [0.88363585]]
# Loss:
# 8.523966681442395e-05
#
#
# --> 86
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90828043]
#  [0.86881105]
#  [0.88373304]]
# Loss:
# 8.475261057571436e-05
#
#
# --> 87
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90836048]
#  [0.86890558]
#  [0.88382654]]
# Loss:
# 8.429978369583986e-05
#
#
# --> 88
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90843754]
#  [0.86899647]
#  [0.88391651]]
# Loss:
# 8.387861429933823e-05
#
#
# --> 89
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90851172]
#  [0.86908387]
#  [0.88400309]]
# Loss:
# 8.348673017812926e-05
#
#
# --> 90
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90858313]
#  [0.8691679 ]
#  [0.88408642]]
# Loss:
# 8.3121942602042e-05
#
#
# --> 91
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90865189]
#  [0.86924872]
#  [0.88416662]]
# Loss:
# 8.278223151636978e-05
#
#
# --> 92
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90871811]
#  [0.86932644]
#  [0.88424382]]
# Loss:
# 8.246573199956489e-05
#
#
# --> 93
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90878188]
#  [0.8694012 ]
#  [0.88431814]]
# Loss:
# 8.21707218666616e-05
#
#
# --> 94
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90884331]
#  [0.86947309]
#  [0.88438969]]
# Loss:
# 8.189561031517797e-05
#
#
# --> 95
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90890247]
#  [0.86954225]
#  [0.88445859]]
# Loss:
# 8.163892752024456e-05
#
#
# --> 96
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90895948]
#  [0.86960876]
#  [0.88452493]]
# Loss:
# 8.139931509465889e-05
#
#
# --> 97
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9090144 ]
#  [0.86967275]
#  [0.88458881]]
# Loss:
# 8.117551733756926e-05
#
#
# --> 98
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90906732]
#  [0.8697343 ]
#  [0.88465034]]
# Loss:
# 8.096637320269392e-05
#
#
# --> 99
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90911831]
#  [0.86979351]
#  [0.88470959]]
# Loss:
# 8.077080892349285e-05
#
#
# --> 100
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90916746]
#  [0.86985047]
#  [0.88476667]]
# Loss:
# 8.05878312384376e-05
#
#
# --> 101
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90921483]
#  [0.86990527]
#  [0.88482165]]
# Loss:
# 8.04165211649055e-05
#
#
# --> 102
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9092605 ]
#  [0.86995799]
#  [0.88487462]]
# Loss:
# 8.02560282747543e-05
#
#
# --> 103
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90930452]
#  [0.87000871]
#  [0.88492565]]
# Loss:
# 8.01055654291013e-05
#
#
# --> 104
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90934696]
#  [0.8700575 ]
#  [0.88497481]]
# Loss:
# 7.996440393347825e-05
#
#
# --> 105
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90938788]
#  [0.87010445]
#  [0.88502218]]
# Loss:
# 7.983186907815997e-05
#
#
# --> 106
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90942734]
#  [0.87014961]
#  [0.88506783]]
# Loss:
# 7.970733603150172e-05
#
#
# --> 107
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9094654 ]
#  [0.87019306]
#  [0.88511181]]
# Loss:
# 7.959022605700431e-05
#
#
# --> 108
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9095021 ]
#  [0.87023486]
#  [0.8851542 ]]
# Loss:
# 7.948000302739063e-05
#
#
# --> 109
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9095375 ]
#  [0.87027507]
#  [0.88519506]]
# Loss:
# 7.937617021131299e-05
#
#
# --> 110
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90957165]
#  [0.87031376]
#  [0.88523443]]
# Loss:
# 7.927826731041607e-05
#
#
# --> 111
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90960459]
#  [0.87035098]
#  [0.88527239]]
# Loss:
# 7.918586772640128e-05
#
#
# --> 112
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90963638]
#  [0.87038678]
#  [0.88530897]]
# Loss:
# 7.909857603948045e-05
#
#
# --> 113
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90966704]
#  [0.87042123]
#  [0.88534424]]
# Loss:
# 7.901602568121481e-05
#
#
# --> 114
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90969664]
#  [0.87045436]
#  [0.88537823]]
# Loss:
# 7.89378767861398e-05
#
#
# --> 115
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9097252 ]
#  [0.87048623]
#  [0.88541101]]
# Loss:
# 7.886381420789533e-05
#
#
# --> 116
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90975276]
#  [0.87051689]
#  [0.88544261]]
# Loss:
# 7.879354568681888e-05
#
#
# --> 117
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90977937]
#  [0.87054638]
#  [0.88547308]]
# Loss:
# 7.872680015698768e-05
#
#
# --> 118
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90980505]
#  [0.87057474]
#  [0.88550245]]
# Loss:
# 7.86633261817281e-05
#
#
# --> 119
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90982984]
#  [0.87060201]
#  [0.88553078]]
# Loss:
# 7.860289050749948e-05
#
#
# --> 120
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90985378]
#  [0.87062824]
#  [0.8855581 ]]
# Loss:
# 7.854527672690212e-05
#
#
# --> 121
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9098769 ]
#  [0.87065347]
#  [0.88558444]]
# Loss:
# 7.849028404229414e-05
#
#
# --> 122
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90989922]
#  [0.87067773]
#  [0.88560984]]
# Loss:
# 7.843772612221887e-05
#
#
# --> 123
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90992077]
#  [0.87070105]
#  [0.88563435]]
# Loss:
# 7.838743004344177e-05
#
#
# --> 124
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90994159]
#  [0.87072348]
#  [0.88565798]]
# Loss:
# 7.833923531202432e-05
#
#
# --> 125
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9099617 ]
#  [0.87074504]
#  [0.88568077]]
# Loss:
# 7.829299295731647e-05
#
#
# --> 126
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90998113]
#  [0.87076576]
#  [0.88570276]]
# Loss:
# 7.824856469332453e-05
#
#
# --> 127
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9099999 ]
#  [0.87078569]
#  [0.88572397]]
# Loss:
# 7.820582214228973e-05
#
#
# --> 128
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91001804]
#  [0.87080483]
#  [0.88574443]]
# Loss:
# 7.816464611572919e-05
#
#
# --> 129
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91003556]
#  [0.87082324]
#  [0.88576417]]
# Loss:
# 7.812492594859028e-05
#
#
# --> 130
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9100525 ]
#  [0.87084092]
#  [0.88578321]]
# Loss:
# 7.808655888249582e-05
#
#
# --> 131
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91006887]
#  [0.87085791]
#  [0.88580158]]
# Loss:
# 7.804944949437745e-05
#
#
# --> 132
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91008469]
#  [0.87087424]
#  [0.88581931]]
# Loss:
# 7.801350916705101e-05
#
#
# --> 133
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91009999]
#  [0.87088992]
#  [0.88583641]]
# Loss:
# 7.797865559862738e-05
#
#
# --> 134
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91011478]
#  [0.87090498]
#  [0.88585292]]
# Loss:
# 7.79448123478178e-05
#
#
# --> 135
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91012908]
#  [0.87091945]
#  [0.88586885]]
# Loss:
# 7.791190841245281e-05
#
#
# --> 136
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91014291]
#  [0.87093334]
#  [0.88588422]]
# Loss:
# 7.787987783875654e-05
#
#
# --> 137
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91015629]
#  [0.87094667]
#  [0.88589906]]
# Loss:
# 7.784865935906434e-05
#
#
# --> 138
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91016923]
#  [0.87095947]
#  [0.88591337]]
# Loss:
# 7.781819605589962e-05
#
#
# --> 139
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91018175]
#  [0.87097176]
#  [0.88592719]]
# Loss:
# 7.778843505041488e-05
#
#
# --> 140
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91019386]
#  [0.87098355]
#  [0.88594053]]
# Loss:
# 7.775932721345516e-05
#
#
# --> 141
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91020558]
#  [0.87099486]
#  [0.88595341]]
# Loss:
# 7.773082689751905e-05
#
#
# --> 142
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91021692]
#  [0.87100571]
#  [0.88596584]]
# Loss:
# 7.770289168810569e-05
#
#
# --> 143
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9102279 ]
#  [0.87101612]
#  [0.88597784]]
# Loss:
# 7.767548217302811e-05
#
#
# --> 144
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91023853]
#  [0.87102609]
#  [0.88598943]]
# Loss:
# 7.764856172835049e-05
#
#
# --> 145
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91024882]
#  [0.87103566]
#  [0.88600062]]
# Loss:
# 7.76220963197609e-05
#
#
# --> 146
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91025879]
#  [0.87104483]
#  [0.88601142]]
# Loss:
# 7.759605431822748e-05
#
#
# --> 147
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91026844]
#  [0.87105361]
#  [0.88602185]]
# Loss:
# 7.757040632890457e-05
#
#
# --> 148
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91027779]
#  [0.87106202]
#  [0.88603192]]
# Loss:
# 7.754512503233829e-05
#
#
# --> 149
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91028685]
#  [0.87107008]
#  [0.88604165]]
# Loss:
# 7.752018503703116e-05
#
#
# --> 150
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91029562]
#  [0.87107779]
#  [0.88605105]]
# Loss:
# 7.749556274260531e-05
#
#
# --> 151
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91030413]
#  [0.87108517]
#  [0.88606012]]
# Loss:
# 7.74712362127386e-05
#
#
# --> 152
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91031237]
#  [0.87109224]
#  [0.88606889]]
# Loss:
# 7.744718505719324e-05
#
#
# --> 153
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91032036]
#  [0.87109899]
#  [0.88607735]]
# Loss:
# 7.742339032227559e-05
#
#
# --> 154
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91032811]
#  [0.87110545]
#  [0.88608554]]
# Loss:
# 7.739983438911499e-05
#
#
# --> 155
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91033562]
#  [0.87111162]
#  [0.88609344]]
# Loss:
# 7.737650087920004e-05
#
#
# --> 156
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91034291]
#  [0.87111751]
#  [0.88610108]]
# Loss:
# 7.735337456663922e-05
#
#
# --> 157
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91034998]
#  [0.87112314]
#  [0.88610846]]
# Loss:
# 7.733044129668442e-05
#
#
# --> 158
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91035684]
#  [0.87112852]
#  [0.88611559]]
# Loss:
# 7.730768791003407e-05
#
#
# --> 159
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9103635 ]
#  [0.87113364]
#  [0.88612248]]
# Loss:
# 7.728510217254185e-05
#
#
# --> 160
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91036996]
#  [0.87113853]
#  [0.88612914]]
# Loss:
# 7.726267270989058e-05
#
#
# --> 161
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91037624]
#  [0.87114319]
#  [0.88613558]]
# Loss:
# 7.724038894693538e-05
#
#
# --> 162
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91038233]
#  [0.87114762]
#  [0.8861418 ]]
# Loss:
# 7.721824105133114e-05
#
#
# --> 163
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91038825]
#  [0.87115184]
#  [0.88614782]]
# Loss:
# 7.71962198811669e-05
#
#
# --> 164
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.910394  ]
#  [0.87115586]
#  [0.88615364]]
# Loss:
# 7.717431693630042e-05
#
#
# --> 165
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91039958]
#  [0.87115968]
#  [0.88615926]]
# Loss:
# 7.715252431316197e-05
#
#
# --> 166
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91040502]
#  [0.8711633 ]
#  [0.8861647 ]]
# Loss:
# 7.713083466272923e-05
#
#
# --> 167
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91041029]
#  [0.87116674]
#  [0.88616997]]
# Loss:
# 7.710924115150263e-05
#
#
# --> 168
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91041543]
#  [0.87117   ]
#  [0.88617506]]
# Loss:
# 7.708773742521744e-05
#
#
# --> 169
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91042042]
#  [0.87117309]
#  [0.88617998]]
# Loss:
# 7.706631757514428e-05
#
#
# --> 170
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91042528]
#  [0.87117602]
#  [0.88618474]]
# Loss:
# 7.704497610673895e-05
#
#
# --> 171
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91043   ]
#  [0.87117878]
#  [0.88618935]]
# Loss:
# 7.702370791054084e-05
#
#
# --> 172
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9104346 ]
#  [0.8711814 ]
#  [0.88619381]]
# Loss:
# 7.70025082351028e-05
#
#
# --> 173
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91043908]
#  [0.87118386]
#  [0.88619812]]
# Loss:
# 7.698137266183335e-05
#
#
# --> 174
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91044344]
#  [0.87118618]
#  [0.8862023 ]]
# Loss:
# 7.6960297081622e-05
#
#
# --> 175
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91044769]
#  [0.87118836]
#  [0.88620635]]
# Loss:
# 7.693927767310013e-05
#
#
# --> 176
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91045183]
#  [0.87119041]
#  [0.88621026]]
# Loss:
# 7.691831088245078e-05
#
#
# --> 177
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91045586]
#  [0.87119233]
#  [0.88621405]]
# Loss:
# 7.689739340461385e-05
#
#
# --> 178
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9104598 ]
#  [0.87119412]
#  [0.88621772]]
# Loss:
# 7.687652216584839e-05
#
#
# --> 179
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91046363]
#  [0.8711958 ]
#  [0.88622128]]
# Loss:
# 7.685569430749173e-05
#
#
# --> 180
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91046737]
#  [0.87119736]
#  [0.88622472]]
# Loss:
# 7.683490717087743e-05
#
#
# --> 181
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91047102]
#  [0.87119881]
#  [0.88622805]]
# Loss:
# 7.681415828331296e-05
#
#
# --> 182
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91047458]
#  [0.87120016]
#  [0.88623129]]
# Loss:
# 7.679344534504011e-05
#
#
# --> 183
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91047806]
#  [0.8712014 ]
#  [0.88623442]]
# Loss:
# 7.677276621710989e-05
#
#
# --> 184
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91048145]
#  [0.87120254]
#  [0.88623746]]
# Loss:
# 7.675211891011583e-05
#
#
# --> 185
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91048477]
#  [0.87120358]
#  [0.8862404 ]]
# Loss:
# 7.673150157371611e-05
#
#
# --> 186
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91048801]
#  [0.87120454]
#  [0.88624325]]
# Loss:
# 7.671091248688811e-05
#
#
# --> 187
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91049118]
#  [0.8712054 ]
#  [0.88624602]]
# Loss:
# 7.66903500488732e-05
#
#
# --> 188
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91049428]
#  [0.87120618]
#  [0.8862487 ]]
# Loss:
# 7.666981277075012e-05
#
#
# --> 189
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9104973 ]
#  [0.87120687]
#  [0.88625131]]
# Loss:
# 7.66492992676056e-05
#
#
# --> 190
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91050027]
#  [0.87120749]
#  [0.88625383]]
# Loss:
# 7.662880825125641e-05
#
#
# --> 191
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91050317]
#  [0.87120802]
#  [0.88625628]]
# Loss:
# 7.660833852347045e-05
#
#
# --> 192
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91050601]
#  [0.87120849]
#  [0.88625866]]
# Loss:
# 7.65878889696761e-05
#
#
# --> 193
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91050879]
#  [0.87120888]
#  [0.88626097]]
# Loss:
# 7.656745855310876e-05
#
#
# --> 194
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91051151]
#  [0.8712092 ]
#  [0.88626321]]
# Loss:
# 7.654704630936079e-05
#
#
# --> 195
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91051418]
#  [0.87120945]
#  [0.88626539]]
# Loss:
# 7.652665134131685e-05
#
#
# --> 196
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91051679]
#  [0.87120964]
#  [0.88626751]]
# Loss:
# 7.650627281446063e-05
#
#
# --> 197
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91051936]
#  [0.87120977]
#  [0.88626956]]
# Loss:
# 7.64859099524793e-05
#
#
# --> 198
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91052187]
#  [0.87120984]
#  [0.88627156]]
# Loss:
# 7.646556203320485e-05
#
#
# --> 199
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91052434]
#  [0.87120985]
#  [0.8862735 ]]
# Loss:
# 7.644522838481963e-05
#
#
# --> 200
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91052676]
#  [0.87120981]
#  [0.88627539]]
# Loss:
# 7.642490838233497e-05
#
#
# --> 201
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91052914]
#  [0.87120971]
#  [0.88627722]]
# Loss:
# 7.640460144432594e-05
#
#
# --> 202
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91053148]
#  [0.87120956]
#  [0.88627901]]
# Loss:
# 7.63843070298809e-05
#
#
# --> 203
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91053377]
#  [0.87120936]
#  [0.88628074]]
# Loss:
# 7.63640246357629e-05
#
#
# --> 204
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91053602]
#  [0.87120911]
#  [0.88628243]]
# Loss:
# 7.634375379378122e-05
#
#
# --> 205
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91053824]
#  [0.87120881]
#  [0.88628408]]
# Loss:
# 7.632349406834882e-05
#
#
# --> 206
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91054042]
#  [0.87120847]
#  [0.88628568]]
# Loss:
# 7.630324505419107e-05
#
#
# --> 207
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91054256]
#  [0.87120809]
#  [0.88628724]]
# Loss:
# 7.628300637423553e-05
#
#
# --> 208
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91054467]
#  [0.87120767]
#  [0.88628876]]
# Loss:
# 7.626277767763579e-05
#
#
# --> 209
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91054675]
#  [0.8712072 ]
#  [0.88629024]]
# Loss:
# 7.624255863794673e-05
#
#
# --> 210
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91054879]
#  [0.8712067 ]
#  [0.88629168]]
# Loss:
# 7.622234895141433e-05
#
#
# --> 211
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91055081]
#  [0.87120616]
#  [0.88629309]]
# Loss:
# 7.6202148335389e-05
#
#
# --> 212
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91055279]
#  [0.87120558]
#  [0.88629446]]
# Loss:
# 7.618195652685063e-05
#
#
# --> 213
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91055475]
#  [0.87120497]
#  [0.8862958 ]]
# Loss:
# 7.616177328104548e-05
#
#
# --> 214
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91055668]
#  [0.87120433]
#  [0.8862971 ]]
# Loss:
# 7.614159837020144e-05
#
#
# --> 215
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91055858]
#  [0.87120365]
#  [0.88629838]]
# Loss:
# 7.612143158234628e-05
#
#
# --> 216
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91056045]
#  [0.87120294]
#  [0.88629962]]
# Loss:
# 7.610127272020308e-05
#
#
# --> 217
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9105623 ]
#  [0.87120221]
#  [0.88630084]]
# Loss:
# 7.608112160016298e-05
#
#
# --> 218
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91056413]
#  [0.87120144]
#  [0.88630202]]
# Loss:
# 7.606097805132964e-05
#
#
# --> 219
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91056593]
#  [0.87120065]
#  [0.88630318]]
# Loss:
# 7.604084191463455e-05
#
#
# --> 220
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91056771]
#  [0.87119982]
#  [0.88630432]]
# Loss:
# 7.602071304201604e-05
#
#
# --> 221
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91056947]
#  [0.87119898]
#  [0.88630542]]
# Loss:
# 7.600059129563135e-05
#
#
# --> 222
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91057121]
#  [0.8711981 ]
#  [0.88630651]]
# Loss:
# 7.598047654716843e-05
#
#
# --> 223
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91057293]
#  [0.87119721]
#  [0.88630757]]
# Loss:
# 7.59603686771629e-05
#
#
# --> 224
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91057463]
#  [0.87119629]
#  [0.88630861]]
# Loss:
# 7.594026757438482e-05
#
#
# --> 225
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91057631]
#  [0.87119535]
#  [0.88630962]]
# Loss:
# 7.592017313526871e-05
#
#
# --> 226
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91057798]
#  [0.87119438]
#  [0.88631062]]
# Loss:
# 7.590008526337102e-05
#
#
# --> 227
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91057962]
#  [0.8711934 ]
#  [0.88631159]]
# Loss:
# 7.588000386887649e-05
#
#
# --> 228
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91058125]
#  [0.87119239]
#  [0.88631255]]
# Loss:
# 7.585992886813743e-05
#
#
# --> 229
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91058287]
#  [0.87119137]
#  [0.88631348]]
# Loss:
# 7.583986018323953e-05
#
#
# --> 230
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91058446]
#  [0.87119033]
#  [0.8863144 ]]
# Loss:
# 7.581979774160312e-05
#
#
# --> 231
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91058605]
#  [0.87118927]
#  [0.8863153 ]]
# Loss:
# 7.57997414756122e-05
#
#
# --> 232
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91058761]
#  [0.87118819]
#  [0.88631618]]
# Loss:
# 7.577969132226642e-05
#
#
# --> 233
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91058917]
#  [0.87118709]
#  [0.88631705]]
# Loss:
# 7.575964722285897e-05
#
#
# --> 234
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91059071]
#  [0.87118598]
#  [0.8863179 ]]
# Loss:
# 7.573960912267567e-05
#
#
# --> 235
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91059224]
#  [0.87118486]
#  [0.88631874]]
# Loss:
# 7.571957697071944e-05
#
#
# --> 236
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91059375]
#  [0.87118372]
#  [0.88631956]]
# Loss:
# 7.569955071945307e-05
#
#
# --> 237
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91059525]
#  [0.87118256]
#  [0.88632037]]
# Loss:
# 7.567953032454535e-05
#
#
# --> 238
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91059675]
#  [0.87118139]
#  [0.88632116]]
# Loss:
# 7.565951574466113e-05
#
#
# --> 239
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91059822]
#  [0.87118021]
#  [0.88632194]]
# Loss:
# 7.563950694125041e-05
#
#
# --> 240
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91059969]
#  [0.87117901]
#  [0.88632271]]
# Loss:
# 7.561950387834548e-05
#
#
# --> 241
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91060115]
#  [0.8711778 ]
#  [0.88632346]]
# Loss:
# 7.559950652238674e-05
#
#
# --> 242
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9106026 ]
#  [0.87117658]
#  [0.88632421]]
# Loss:
# 7.557951484205469e-05
#
#
# --> 243
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91060404]
#  [0.87117535]
#  [0.88632494]]
# Loss:
# 7.555952880811505e-05
#
#
# --> 244
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91060547]
#  [0.87117411]
#  [0.88632566]]
# Loss:
# 7.553954839326756e-05
#
#
# --> 245
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91060689]
#  [0.87117285]
#  [0.88632637]]
# Loss:
# 7.551957357201536e-05
#
#
# --> 246
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9106083 ]
#  [0.87117159]
#  [0.88632707]]
# Loss:
# 7.549960432054463e-05
#
#
# --> 247
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9106097 ]
#  [0.87117031]
#  [0.88632777]]
# Loss:
# 7.547964061658849e-05
#
#
# --> 248
#
# Input (scaled):
# [[0.4 0.9]
# ...
#
#
# --> 918
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91136635]
#  [0.87018144]
#  [0.88662183]]
# Loss:
# 6.320455930656779e-05
#
#
# --> 919
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91136741]
#  [0.87018002]
#  [0.88662226]]
# Loss:
# 6.318783337611309e-05
#
#
# --> 920
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91136848]
#  [0.8701786 ]
#  [0.88662269]]
# Loss:
# 6.317111183378672e-05
#
#
# --> 921
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91136954]
#  [0.87017718]
#  [0.88662312]]
# Loss:
# 6.315439467841617e-05
#
#
# --> 922
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9113706 ]
#  [0.87017576]
#  [0.88662355]]
# Loss:
# 6.313768190883375e-05
#
#
# --> 923
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137166]
#  [0.87017434]
#  [0.88662398]]
# Loss:
# 6.312097352386411e-05
#
#
# --> 924
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137272]
#  [0.87017292]
#  [0.88662441]]
# Loss:
# 6.310426952234133e-05
#
#
# --> 925
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137379]
#  [0.8701715 ]
#  [0.88662483]]
# Loss:
# 6.308756990309223e-05
#
#
# --> 926
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137485]
#  [0.87017008]
#  [0.88662526]]
# Loss:
# 6.307087466494783e-05
#
#
# --> 927
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137591]
#  [0.87016866]
#  [0.88662569]]
# Loss:
# 6.305418380674281e-05
#
#
# --> 928
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137697]
#  [0.87016724]
#  [0.88662612]]
# Loss:
# 6.303749732730283e-05
#
#
# --> 929
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137803]
#  [0.87016582]
#  [0.88662655]]
# Loss:
# 6.302081522546265e-05
#
#
# --> 930
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91137909]
#  [0.8701644 ]
#  [0.88662698]]
# Loss:
# 6.300413750005253e-05
#
#
# --> 931
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138015]
#  [0.87016299]
#  [0.88662741]]
# Loss:
# 6.298746414990594e-05
#
#
# --> 932
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138121]
#  [0.87016157]
#  [0.88662784]]
# Loss:
# 6.297079517385568e-05
#
#
# --> 933
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138228]
#  [0.87016015]
#  [0.88662827]]
# Loss:
# 6.295413057073401e-05
#
#
# --> 934
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138334]
#  [0.87015873]
#  [0.8866287 ]]
# Loss:
# 6.293747033937464e-05
#
#
# --> 935
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9113844 ]
#  [0.87015731]
#  [0.88662913]]
# Loss:
# 6.292081447861204e-05
#
#
# --> 936
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138546]
#  [0.8701559 ]
#  [0.88662956]]
# Loss:
# 6.29041629872777e-05
#
#
# --> 937
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138652]
#  [0.87015448]
#  [0.88662999]]
# Loss:
# 6.288751586421033e-05
#
#
# --> 938
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138758]
#  [0.87015306]
#  [0.88663042]]
# Loss:
# 6.287087310824132e-05
#
#
# --> 939
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138864]
#  [0.87015165]
#  [0.88663085]]
# Loss:
# 6.285423471820667e-05
#
#
# --> 940
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91138969]
#  [0.87015023]
#  [0.88663128]]
# Loss:
# 6.283760069294277e-05
#
#
# --> 941
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139075]
#  [0.87014881]
#  [0.8866317 ]]
# Loss:
# 6.282097103128434e-05
#
#
# --> 942
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139181]
#  [0.8701474 ]
#  [0.88663213]]
# Loss:
# 6.28043457320703e-05
#
#
# --> 943
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139287]
#  [0.87014598]
#  [0.88663256]]
# Loss:
# 6.278772479413352e-05
#
#
# --> 944
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139393]
#  [0.87014456]
#  [0.88663299]]
# Loss:
# 6.277110821631444e-05
#
#
# --> 945
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139499]
#  [0.87014315]
#  [0.88663342]]
# Loss:
# 6.275449599744765e-05
#
#
# --> 946
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139605]
#  [0.87014173]
#  [0.88663385]]
# Loss:
# 6.273788813637277e-05
#
#
# --> 947
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139711]
#  [0.87014032]
#  [0.88663428]]
# Loss:
# 6.272128463192835e-05
#
#
# --> 948
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139817]
#  [0.8701389 ]
#  [0.88663471]]
# Loss:
# 6.270468548295051e-05
#
#
# --> 949
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91139922]
#  [0.87013749]
#  [0.88663514]]
# Loss:
# 6.268809068828182e-05
#
#
# --> 950
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140028]
#  [0.87013607]
#  [0.88663557]]
# Loss:
# 6.267150024675612e-05
#
#
# --> 951
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140134]
#  [0.87013466]
#  [0.886636  ]]
# Loss:
# 6.26549141572183e-05
#
#
# --> 952
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9114024 ]
#  [0.87013324]
#  [0.88663643]]
# Loss:
# 6.263833241850659e-05
#
#
# --> 953
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140345]
#  [0.87013183]
#  [0.88663686]]
# Loss:
# 6.26217550294592e-05
#
#
# --> 954
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140451]
#  [0.87013041]
#  [0.88663729]]
# Loss:
# 6.26051819889196e-05
#
#
# --> 955
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140557]
#  [0.870129  ]
#  [0.88663772]]
# Loss:
# 6.258861329572756e-05
#
#
# --> 956
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140663]
#  [0.87012759]
#  [0.88663815]]
# Loss:
# 6.257204894872524e-05
#
#
# --> 957
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140768]
#  [0.87012617]
#  [0.88663857]]
# Loss:
# 6.255548894675145e-05
#
#
# --> 958
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91140874]
#  [0.87012476]
#  [0.886639  ]]
# Loss:
# 6.253893328865365e-05
#
#
# --> 959
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9114098 ]
#  [0.87012335]
#  [0.88663943]]
# Loss:
# 6.252238197326908e-05
#
#
# --> 960
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141085]
#  [0.87012193]
#  [0.88663986]]
# Loss:
# 6.250583499944327e-05
#
#
# --> 961
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141191]
#  [0.87012052]
#  [0.88664029]]
# Loss:
# 6.248929236601878e-05
#
#
# --> 962
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141296]
#  [0.87011911]
#  [0.88664072]]
# Loss:
# 6.247275407184127e-05
#
#
# --> 963
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141402]
#  [0.87011769]
#  [0.88664115]]
# Loss:
# 6.245622011575128e-05
#
#
# --> 964
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141508]
#  [0.87011628]
#  [0.88664158]]
# Loss:
# 6.2439690496596e-05
#
#
# --> 965
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141613]
#  [0.87011487]
#  [0.88664201]]
# Loss:
# 6.24231652132184e-05
#
#
# --> 966
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141719]
#  [0.87011346]
#  [0.88664244]]
# Loss:
# 6.24066442644631e-05
#
#
# --> 967
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91141824]
#  [0.87011205]
#  [0.88664287]]
# Loss:
# 6.239012764917537e-05
#
#
# --> 968
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9114193 ]
#  [0.87011063]
#  [0.8866433 ]]
# Loss:
# 6.237361536620456e-05
#
#
# --> 969
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142035]
#  [0.87010922]
#  [0.88664373]]
# Loss:
# 6.235710741439017e-05
#
#
# --> 970
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142141]
#  [0.87010781]
#  [0.88664416]]
# Loss:
# 6.234060379258573e-05
#
#
# --> 971
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142246]
#  [0.8701064 ]
#  [0.88664459]]
# Loss:
# 6.232410449963362e-05
#
#
# --> 972
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142352]
#  [0.87010499]
#  [0.88664502]]
# Loss:
# 6.230760953438363e-05
#
#
# --> 973
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142457]
#  [0.87010358]
#  [0.88664544]]
# Loss:
# 6.229111889568043e-05
#
#
# --> 974
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142562]
#  [0.87010217]
#  [0.88664587]]
# Loss:
# 6.227463258237347e-05
#
#
# --> 975
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142668]
#  [0.87010076]
#  [0.8866463 ]]
# Loss:
# 6.225815059331147e-05
#
#
# --> 976
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142773]
#  [0.87009935]
#  [0.88664673]]
# Loss:
# 6.22416729273419e-05
#
#
# --> 977
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142879]
#  [0.87009794]
#  [0.88664716]]
# Loss:
# 6.22251995833156e-05
#
#
# --> 978
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91142984]
#  [0.87009653]
#  [0.88664759]]
# Loss:
# 6.220873056008004e-05
#
#
# --> 979
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91143089]
#  [0.87009512]
#  [0.88664802]]
# Loss:
# 6.21922658564858e-05
#
#
# --> 980
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91143195]
#  [0.87009371]
#  [0.88664845]]
# Loss:
# 6.217580547138248e-05
#
#
# --> 981
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.911433  ]
#  [0.8700923 ]
#  [0.88664888]]
# Loss:
# 6.215934940362161e-05
#
#
# --> 982
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91143405]
#  [0.87009089]
#  [0.88664931]]
# Loss:
# 6.214289765205088e-05
#
#
# --> 983
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9114351 ]
#  [0.87008948]
#  [0.88664974]]
# Loss:
# 6.212645021552593e-05
#
#
# --> 984
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91143616]
#  [0.87008807]
#  [0.88665017]]
# Loss:
# 6.211000709289542e-05
#
#
# --> 985
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91143721]
#  [0.87008667]
#  [0.8866506 ]]
# Loss:
# 6.209356828301104e-05
#
#
# --> 986
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91143826]
#  [0.87008526]
#  [0.88665103]]
# Loss:
# 6.207713378472678e-05
#
#
# --> 987
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91143931]
#  [0.87008385]
#  [0.88665146]]
# Loss:
# 6.206070359689262e-05
#
#
# --> 988
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144037]
#  [0.87008244]
#  [0.88665189]]
# Loss:
# 6.204427771836422e-05
#
#
# --> 989
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144142]
#  [0.87008103]
#  [0.88665231]]
# Loss:
# 6.202785614799155e-05
#
#
# --> 990
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144247]
#  [0.87007963]
#  [0.88665274]]
# Loss:
# 6.201143888463134e-05
#
#
# --> 991
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144352]
#  [0.87007822]
#  [0.88665317]]
# Loss:
# 6.199502592713787e-05
#
#
# --> 992
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144457]
#  [0.87007681]
#  [0.8866536 ]]
# Loss:
# 6.197861727436303e-05
#
#
# --> 993
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144562]
#  [0.8700754 ]
#  [0.88665403]]
# Loss:
# 6.19622129251629e-05
#
#
# --> 994
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144667]
#  [0.870074  ]
#  [0.88665446]]
# Loss:
# 6.194581287839165e-05
#
#
# --> 995
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144772]
#  [0.87007259]
#  [0.88665489]]
# Loss:
# 6.192941713290596e-05
#
#
# --> 996
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144878]
#  [0.87007118]
#  [0.88665532]]
# Loss:
# 6.191302568755976e-05
#
#
# --> 997
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91144983]
#  [0.87006978]
#  [0.88665575]]
# Loss:
# 6.189663854121314e-05
#
#
# --> 998
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91145088]
#  [0.87006837]
#  [0.88665618]]
# Loss:
# 6.188025569271736e-05
#
#
# --> 999
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.91145193]
#  [0.87006697]
#  [0.88665661]]
# Loss:
# 6.186387714093118e-05
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [[1. 1.]]
# Output:
# [[0.92195207]]
